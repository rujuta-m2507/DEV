# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('winequalityN.csv')

# %%
df2=pd.read_csv('winequality-red.csv')

# %%
a=df2.head(500)
a
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 495           10.7              0.35         0.53             2.6      0.070
# 496            7.8              0.52         0.25             1.9      0.081
# 497            7.2              0.34         0.32             2.5      0.090
# 498           10.7              0.35         0.53             2.6      0.070
# 499            8.7              0.69         0.31             3.0      0.086
#
# ...

# %%
df.isnull()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 6492  False          False             False        False           False
# 6493  False          False             False        False           False
# 6494  False          False             False        False           False
# 6495  False          False             False        False           False
# 6496  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %%
b=df.head(500)
b
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    white            7.0             0.270         0.36            20.7
# 1    white            6.3             0.300         0.34             1.6
# 2    white            8.1             0.280         0.40             6.9
# 3    white            7.2             0.230         0.32             8.5
# 4    white            7.2             0.230         0.32             8.5
# ..     ...            ...               ...          ...             ...
# 495  white            5.7             0.440         0.13             7.0
# 496  white            7.2             0.400         0.62            10.8
# 497  white            6.8             0.230         0.32             1.6
# 498  white            5.7             0.335         0.34             1.0
# 499  white            7.2             0.400         0.62            10.8
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
x=df.pH
y=df2.alcohol

# %%
plt.title("Line graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x,color ="blue")

# %%
plt.title("Line graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(y,color ="green")

# %%
plt.title("Bar graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.bar(a.pH, b.alcohol, color ="yellow")
# Out:
# <BarContainer object of 500 artists>

# %%
plt.title("Histogram")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.hist(x,color='purple')
# Out:
# (array([  16.,  334., 1231., 2110., 1660.,  800.,  262.,   59.,   12.,
#            4.]),
#  array([2.72 , 2.849, 2.978, 3.107, 3.236, 3.365, 3.494, 3.623, 3.752,
#         3.881, 4.01 ]),
#  <a list of 10 Patch objects>)

# %%
plt.title("lollipop chart")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.stem(a.pH,b.alcohol)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   after removing the cwd from sys.path.
# <StemContainer object of 3 artists>

# %%
plt.title("scatter plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.scatter(a.pH,b.alcohol,color='red')

# %%
plt.title("Box plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.boxplot(b.alcohol)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f25b9159d50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f25b91295d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f25b89a1290>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f25b9057cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f25b893e590>],
#  'means': []}

# %%
plt.title("stack plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.stackplot(a.pH,b.alcohol,color='blue')

# %%
plt.title("Pie chart")
plt.pie(a.pH)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f25bb9aebd0>,
# ...
#  [Text(1.0999753288998988, 0.007367211925801786, ''),
#   Text(1.0997908470718063, 0.021449771492471396, ''),
#   Text(1.0994429022959986, 0.035004351028856524, ''),
#   Text(1.0989316105453606, 0.0484697363741544, ''),
#   Text(1.098225741762121, 0.0624517424179589, ''),
#   Text(1.0972906996364415, 0.07715646759260629, ''),
#   Text(1.0961954927898467, 0.09140810460361558, ''),
#   Text(1.0949393543582706, 0.10539359694731618, ''),
#   Text(1.0934911208229936, 0.11948710675747967, ''),
#   Text(1.0918716812273592, 0.133477457773739, ''),
#   Text(1.0900957484969305, 0.14727952712076836, ''),
#   Text(1.0881453544507167, 0.16105802552907497, ''),
#   Text(1.0859205651778572, 0.1754323975889384, ''),
#   Text(1.083538473684889, 0.18959002095210922, ''),
#   Text(1.0811347238468618, 0.20284898050660738, ''),
#   Text(1.0786058254363224, 0.2158922725222697, ''),
#   Text(1.0758583856887731, 0.2291914787751656, ''),
# ...
