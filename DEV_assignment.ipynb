# %% [markdown]
# <a href="https://colab.research.google.com/github/rujuta-m2507/DEV/blob/main/DEV_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('International_Report_Passengers.csv',nrows=500)
df.head(500)
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1    06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3    04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 495  02/01/2003  2003      2       14027     PBI       33      13165    MAN
# 496  04/01/2004  2004      4       13342     MKE       45      14312    PVR
# 497  04/01/2009  2009      4       10721     BOS       13      16217    YUL
# 498  05/01/2010  2010      5       13303     MIA       33      12180    HOG
# 499  12/01/2005  2005     12       15016     STL       64      14312    PVR
#
# ...

# %%
x=df.Month
y=df.Charter

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.hist(x)
# Out:
# (array([105.,  62.,  46.,  30.,  32.,  50.,  35.,  20.,  25.,  95.]),
#  array([ 1. ,  2.1,  3.2,  4.3,  5.4,  6.5,  7.6,  8.7,  9.8, 10.9, 12. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(y)
# Out:
# (array([385.,  76.,  21.,   7.,   5.,   2.,   1.,   0.,   1.,   2.]),
#  array([1.00000e+00, 1.26650e+03, 2.53200e+03, 3.79750e+03, 5.06300e+03,
#         6.32850e+03, 7.59400e+03, 8.85950e+03, 1.01250e+04, 1.13905e+04,
#         1.26560e+04]),
#  <a list of 10 Patch objects>)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 500 artists>

# %%
plt.scatter(x,y)

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcc8ec37090>,
# ...
#  [Text(1.099985199045449, 0.005706301862327029, '315'),
#   Text(1.0998484413686138, 0.018259409054819393, '683'),
#   Text(1.099315673316231, 0.03879497907309052, '1010'),
#   Text(1.0985202331607056, 0.05703768347811077, '508'),
#   Text(1.0974220835086563, 0.07526467051359395, '76'),
#   Text(1.0961179144654334, 0.09233372941644377, '35'),
#   Text(1.09552189478956, 0.09915532278547898, '248'),
#   Text(1.0947728840963538, 0.10710897370132762, '2'),
#   Text(1.0932286982541122, 0.12186473367475766, '8'),
#   Text(1.0909093494499595, 0.14112686237093913, '624'),
#   Text(1.088744447265518, 0.15695709142470154, '29'),
#   Text(1.0872313977027943, 0.16711639012744578, '119'),
#   Text(1.0856235517434294, 0.17726111784591078, '49'),
#   Text(1.0839210495765341, 0.18739039005483857, '1464'),
#   Text(1.0829343684874946, 0.19301076018862723, '1877'),
#   Text(1.0802326785534053, 0.20759903705300645, '41'),
# ...

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcc8e28fd50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcc8e293810>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcc8e28f750>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcc8e29a310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcc8e29a850>],
#  'means': []}

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcc8c974a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcc8c97c550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcc8c974490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcc8c983050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcc8c983590>],
#  'means': []}

# %%
plt.plot(x,y)
